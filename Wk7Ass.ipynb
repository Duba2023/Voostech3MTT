# %%
import pandas as pd


top_universities = pd.read_csv('/Users/DUBA LOANS/Desktop/topuniversities.csv')

# %%
top_universities.head()
# Out:
#    sequence  rank                                   university  overall_score  \
# 0         0     1  Massachusetts Institute of Technology (MIT)          100.0
# 1         1     2                      University of Cambridge           99.2
# 2         2     3                         University of Oxford           98.9
# 3         3     4                           Harvard University           98.3
# 4         4     5                          Stanford University           98.1
#
#    academic_reputation  employer_reputation  faculty_student_ratio  \
# 0                100.0                100.0                  100.0
# 1                100.0                100.0                  100.0
# 2                100.0                100.0                  100.0
# 3                100.0                100.0                   98.3
# 4                100.0                100.0                  100.0
#
#    citations_per_faculty  international_faculty_ratio  \
# ...

# %%
#top_universities = top_universities.groupby['faculty_student_ratio' ]['university'].count()
top_universities['university'].value_counts()
# Out:
# university
# Massachusetts Institute of Technology (MIT)     1
# Ludwig-Maximilians-UniversitÃ¤t MÃ¼nchen        1
# Durham University                               1
# Yonsei University                               1
# University of Glasgow                           1
#                                                ..
# University of Michigan-Ann Arbor                1
# The University of Manchester                    1
# McGill University                               1
# University of California, Los Angeles (UCLA)    1
# Uppsala University                              1
# Name: count, Length: 105, dtype: int64

# %%
top_universities.groupby('university')['faculty_student_ratio'].count().plot(kind='bar')
# Out:
# <Axes: xlabel='university'>

# %%
#Raw data from wikipeida
url_link = 'https://en.wikipedia.org/wiki/List_of_largest_companies_by_revenue'

# %%
#Reading a html file
lst_company = pd.read_html(url_link)

# %%
lst_company = lst_company[0] #Dataframe

# %%
#Displaying the first three rows
lst_company.head(3)
# Out:
#   Rank                             Name     Industry      Revenue  \
#   Rank                             Name     Industry USD millions
# 0    1                          Walmart       Retail     $611,289
# 1    2                     Saudi Aramco  Oil and gas     $603,651
# 2    3  State Grid Corporation of China  Electricity     $530,009
#
#         Profit Employees Headquarters[note 1] State-owned               Ref.  \
#   USD millions Employees Headquarters[note 1] State-owned Unnamed: 8_level_1
# 0      $11,680   2100000        United States         NaN                [1]
# 1     $159,069     70496         Saudi Arabia         NaN                [4]
# 2       $8,192    870287                China         NaN                [5]
#
#   Unnamed: 9_level_0
#   Revenue per worker
# 0        $291,090.00
# 1      $8,562,911.37
# 2        $609,004.85

# %%
#lst_company.drop(columns =['Rank'],  axis=1 ,inplace =True )
#lst_company1 = pd.DataFrame(lst_company)
#lst_company1.groupby('Industry')

#lst_company1.drop( columns = ['Rank'] , axis = 1, inplace = True)

# %%
#Taking away the second heading , leaving the first one
lst_company.columns = lst_company.columns.get_level_values(0)

# %%
lst_company.head()
# Out:
#    Rank                             Name     Industry   Revenue    Profit  \
# 0     1                          Walmart       Retail  $611,289   $11,680
# 1     2                     Saudi Aramco  Oil and gas  $603,651  $159,069
# 2     3  State Grid Corporation of China  Electricity  $530,009    $8,192
# 3     4                           Amazon       Retail  $513,983   −$2,722
# 4     5                            Vitol  Commodities  $505,000   $15,000
#
#    Employees Headquarters[note 1]  State-owned    Ref. Unnamed: 9_level_0
# 0    2100000        United States          NaN     [1]        $291,090.00
# 1      70496         Saudi Arabia          NaN     [4]      $8,562,911.37
# 2     870287                China          NaN     [5]        $609,004.85
# 3    1541000        United States          NaN     [6]        $333,538.61
# 4       1560          Switzerland          NaN  [7][8]    $323,717,948.72

# %%
#Renaming the columns
lst_company.rename(columns={"Headquarters[note 1]": "Headquarters"} , inplace=True)

# %%
lst_company.head()
# Out:
#    Rank                             Name     Industry   Revenue    Profit  \
# 0     1                          Walmart       Retail  $611,289   $11,680
# 1     2                     Saudi Aramco  Oil and gas  $603,651  $159,069
# 2     3  State Grid Corporation of China  Electricity  $530,009    $8,192
# 3     4                           Amazon       Retail  $513,983   −$2,722
# 4     5                            Vitol  Commodities  $505,000   $15,000
#
#    Employees   Headquarters  State-owned    Ref. Unnamed: 9_level_0
# 0    2100000  United States          NaN     [1]        $291,090.00
# 1      70496   Saudi Arabia          NaN     [4]      $8,562,911.37
# 2     870287          China          NaN     [5]        $609,004.85
# 3    1541000  United States          NaN     [6]        $333,538.61
# 4       1560    Switzerland          NaN  [7][8]    $323,717,948.72

# %%
#Removing a $ sign from Revenue values
lst_company['Revenue'] = lst_company['Revenue'].str.replace('$', '')

# %%
lst_company.head()
# Out:
#    Rank                             Name     Industry  Revenue    Profit  \
# 0     1                          Walmart       Retail  611,289   $11,680
# 1     2                     Saudi Aramco  Oil and gas  603,651  $159,069
# 2     3  State Grid Corporation of China  Electricity  530,009    $8,192
# 3     4                           Amazon       Retail  513,983   −$2,722
# 4     5                            Vitol  Commodities  505,000   $15,000
#
#    Employees   Headquarters  State-owned    Ref. Unnamed: 9_level_0
# 0    2100000  United States          NaN     [1]        $291,090.00
# 1      70496   Saudi Arabia          NaN     [4]      $8,562,911.37
# 2     870287          China          NaN     [5]        $609,004.85
# 3    1541000  United States          NaN     [6]        $333,538.61
# 4       1560    Switzerland          NaN  [7][8]    $323,717,948.72

# %%
lst_company['Profit'] = lst_company['Profit'].str.replace('$', '')

# %%
lst_company.head()
# Out:
#    Rank                             Name     Industry  Revenue   Profit  \
# 0     1                          Walmart       Retail  611,289   11,680
# 1     2                     Saudi Aramco  Oil and gas  603,651  159,069
# 2     3  State Grid Corporation of China  Electricity  530,009    8,192
# 3     4                           Amazon       Retail  513,983   −2,722
# 4     5                            Vitol  Commodities  505,000   15,000
#
#    Employees   Headquarters  State-owned    Ref. Unnamed: 9_level_0
# 0    2100000  United States          NaN     [1]        $291,090.00
# 1      70496   Saudi Arabia          NaN     [4]      $8,562,911.37
# 2     870287          China          NaN     [5]        $609,004.85
# 3    1541000  United States          NaN     [6]        $333,538.61
# 4       1560    Switzerland          NaN  [7][8]    $323,717,948.72

# %%
#Deleting a column
lst_company.drop( columns = ['Ref.'], axis = 1, inplace = True)

# %%
lst_company.head()
# Out:
#    Rank                             Name     Industry  Revenue   Profit  \
# 0     1                          Walmart       Retail  611,289   11,680
# 1     2                     Saudi Aramco  Oil and gas  603,651  159,069
# 2     3  State Grid Corporation of China  Electricity  530,009    8,192
# 3     4                           Amazon       Retail  513,983   −2,722
# 4     5                            Vitol  Commodities  505,000   15,000
#
#    Employees   Headquarters  State-owned Unnamed: 9_level_0
# 0    2100000  United States          NaN        $291,090.00
# 1      70496   Saudi Arabia          NaN      $8,562,911.37
# 2     870287          China          NaN        $609,004.85
# 3    1541000  United States          NaN        $333,538.61
# 4       1560    Switzerland          NaN    $323,717,948.72

# %%
lst_company.drop( columns = ['Unnamed: 9_level_0'], axis = 1, inplace = True)

# %%
lst_company.head()
# Out:
#    Rank                             Name     Industry  Revenue   Profit  \
# 0     1                          Walmart       Retail  611,289   11,680
# 1     2                     Saudi Aramco  Oil and gas  603,651  159,069
# 2     3  State Grid Corporation of China  Electricity  530,009    8,192
# 3     4                           Amazon       Retail  513,983   −2,722
# 4     5                            Vitol  Commodities  505,000   15,000
#
#    Employees   Headquarters  State-owned
# 0    2100000  United States          NaN
# 1      70496   Saudi Arabia          NaN
# 2     870287          China          NaN
# 3    1541000  United States          NaN
# 4       1560    Switzerland          NaN

# %%
lst_company['Industry'].value_counts()
# Out:
# Industry
# Oil and gas               13
# Healthcare                 6
# Financials                 5
# Automotive                 5
# Retail                     4
# Commodities                3
# Electronics                3
# Construction               3
# Electricity                2
# Information technology     2
# Conglomerate               2
# Chemicals                  1
# Steel                      1
# Name: count, dtype: int64

# %%
type(lst_company)
# Out:
# pandas.core.frame.DataFrame

# %%
#Grouping the industries and ploting a barchat to know the highest 
lst_company.groupby('Industry')['Name'].count().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Industry'>

# %%
lst_company.head()
# Out:
#    Rank                             Name     Industry  Revenue   Profit  \
# 0     1                          Walmart       Retail  611,289   11,680
# 1     2                     Saudi Aramco  Oil and gas  603,651  159,069
# 2     3  State Grid Corporation of China  Electricity  530,009    8,192
# 3     4                           Amazon       Retail  513,983   −2,722
# 4     5                            Vitol  Commodities  505,000   15,000
#
#    Employees   Headquarters  State-owned
# 0    2100000  United States          NaN
# 1      70496   Saudi Arabia          NaN
# 2     870287          China          NaN
# 3    1541000  United States          NaN
# 4       1560    Switzerland          NaN

# %%
#lst_company['Revenue'] = lst_company['Revenue'].str.replace('Revenue' , 'Revenue($)')

# %%
lst_company
# Out:
#     Rank                                     Name                Industry  \
# 0      1                                  Walmart                  Retail
# 1      2                             Saudi Aramco             Oil and gas
# 2      3          State Grid Corporation of China             Electricity
# 3      4                                   Amazon                  Retail
# 4      5                                    Vitol             Commodities
# 5      6     China National Petroleum Corporation             Oil and gas
# 6      7          China Petrochemical Corporation             Oil and gas
# 7      8                               ExxonMobil             Oil and gas
# 8      9                                    Apple             Electronics
# 9     10                                    Shell             Oil and gas
# 10    11                       UnitedHealth Group              Healthcare
# 11    12                               CVS Health              Healthcare
# ...

# %%
#Renaming columns
lst_company.rename( columns = {'Revenue' : 'Revenue($)'} , inplace = True)
lst_company.rename( columns = {'Profit' : 'Profit($)'} , inplace = True)

# %%
lst_company.head()
# Out:
#    Rank                             Name     Industry Revenue($) Profit($)  \
# 0     1                          Walmart       Retail    611,289    11,680
# 1     2                     Saudi Aramco  Oil and gas    603,651   159,069
# 2     3  State Grid Corporation of China  Electricity    530,009     8,192
# 3     4                           Amazon       Retail    513,983    −2,722
# 4     5                            Vitol  Commodities    505,000    15,000
#
#    Employees   Headquarters  State-owned
# 0    2100000  United States          NaN
# 1      70496   Saudi Arabia          NaN
# 2     870287          China          NaN
# 3    1541000  United States          NaN
# 4       1560    Switzerland          NaN

# %%
# Removing a sign and replacing with nothing
lst_company['Profit($)'] = lst_company['Profit($)'].str.replace('−' , '')

# %%
lst_company.head()
# Out:
#    Rank                             Name     Industry Revenue($) Profit($)  \
# 0     1                          Walmart       Retail    611,289    11,680
# 1     2                     Saudi Aramco  Oil and gas    603,651   159,069
# 2     3  State Grid Corporation of China  Electricity    530,009     8,192
# 3     4                           Amazon       Retail    513,983     2,722
# 4     5                            Vitol  Commodities    505,000    15,000
#
#    Employees   Headquarters  State-owned
# 0    2100000  United States          NaN
# 1      70496   Saudi Arabia          NaN
# 2     870287          China          NaN
# 3    1541000  United States          NaN
# 4       1560    Switzerland          NaN

# %%
#Renaming columns
lst_company.rename( columns = {'Rank' : 'Ranking' , 'Name': ' Company Name'} , inplace = True)

# %%
lst_company.head()
# Out:
#    Ranking                     Company Name     Industry Revenue($) Profit($)  \
# 0        1                          Walmart       Retail    611,289    11,680
# 1        2                     Saudi Aramco  Oil and gas    603,651   159,069
# 2        3  State Grid Corporation of China  Electricity    530,009     8,192
# 3        4                           Amazon       Retail    513,983     2,722
# 4        5                            Vitol  Commodities    505,000    15,000
#
#    Employees   Headquarters  State-owned
# 0    2100000  United States          NaN
# 1      70496   Saudi Arabia          NaN
# 2     870287          China          NaN
# 3    1541000  United States          NaN
# 4       1560    Switzerland          NaN

# %%
#copying lst_company and puting it in lst_company1
lst_company1 = lst_company.copy()

# %%
# Displaying the list of industry and their corresponding numbers of missing values
lst_company1.isnull
# Out:
# <bound method DataFrame.isnull of     Ranking                             Company Name                Industry  \
# 0         1                                  Walmart                  Retail
# 1         2                             Saudi Aramco             Oil and gas
# 2         3          State Grid Corporation of China             Electricity
# 3         4                                   Amazon                  Retail
# 4         5                                    Vitol             Commodities
# 5         6     China National Petroleum Corporation             Oil and gas
# 6         7          China Petrochemical Corporation             Oil and gas
# 7         8                               ExxonMobil             Oil and gas
# 8         9                                    Apple             Electronics
# 9        10                                    Shell             Oil and gas
# 10       11                       UnitedHealth Group              Healthcare
# ...

# %%
#Dropping an industry with the highest missing values 
lst_company1 = lst_company1.drop(index=49)

# %%
lst_company1.isnull().sum()
# Out:
# Ranking           0
#  Company Name     0
# Industry          0
# Revenue($)        0
# Profit($)         0
# Employees         0
# Headquarters      0
# State-owned      49
# dtype: int64
