# %%
#library importation
import pandas as pd

# %%
#reading csv file
fifa_data = pd.read_csv('C:/Users/DUBA LOANS/Desktop/fifa.csv', low_memory = False)

# %%
#display fifa_data
fifa_data
# Out:
#                                                photoUrl  \
# 0      https://cdn.sofifa.com/players/158/023/21_60.png
# 1      https://cdn.sofifa.com/players/020/801/21_60.png
# 2      https://cdn.sofifa.com/players/200/389/21_60.png
# 3      https://cdn.sofifa.com/players/192/985/21_60.png
# 4      https://cdn.sofifa.com/players/190/871/21_60.png
# ...                                                 ...
# 18974  https://cdn.sofifa.com/players/257/710/21_60.png
# 18975  https://cdn.sofifa.com/players/258/736/21_60.png
# 18976  https://cdn.sofifa.com/players/247/223/21_60.png
# 18977  https://cdn.sofifa.com/players/258/760/21_60.png
# 18978  https://cdn.sofifa.com/players/255/958/21_60.png
#
#                            LongName  \
# 0                      Lionel Messi
# 1      C. Ronaldo dos Santos Aveiro
# 2                         Jan Oblak
# 3                   Kevin De Bruyne
# 4        Neymar da Silva Santos Jr.
# ...                             ...
# ...

# %%
#displaying the first 20
fifa_data.head(20)
# Out:
#                                             photoUrl  \
# 0   https://cdn.sofifa.com/players/158/023/21_60.png
# 1   https://cdn.sofifa.com/players/020/801/21_60.png
# 2   https://cdn.sofifa.com/players/200/389/21_60.png
# 3   https://cdn.sofifa.com/players/192/985/21_60.png
# 4   https://cdn.sofifa.com/players/190/871/21_60.png
# 5   https://cdn.sofifa.com/players/188/545/21_60.png
# 6   https://cdn.sofifa.com/players/231/747/21_60.png
# 7   https://cdn.sofifa.com/players/212/831/21_60.png
# 8   https://cdn.sofifa.com/players/209/331/21_60.png
# 9   https://cdn.sofifa.com/players/208/722/21_60.png
# 10  https://cdn.sofifa.com/players/203/376/21_60.png
# 11  https://cdn.sofifa.com/players/192/448/21_60.png
# 12  https://cdn.sofifa.com/players/200/145/21_60.png
# 13  https://cdn.sofifa.com/players/192/119/21_60.png
# 14  https://cdn.sofifa.com/players/167/495/21_60.png
# 15  https://cdn.sofifa.com/players/165/153/21_60.png
# 16  https://cdn.sofifa.com/players/155/862/21_60.png
# ...

# %%
#checking the data type of Column Team & Contract
fifa_data['Team & Contract'].dtype
# Out:
# dtype('O')

# %%
#checking its type
type(fifa_data)
# Out:
# pandas.core.frame.DataFrame

# %%
#Replacing \n\n\n\n with an empty space
fifa_data['Team & Contract'] = fifa_data['Team & Contract'].str. replace('\n\n\n\n', '')

# %%
fifa_data
# Out:
#                                                photoUrl  \
# 0      https://cdn.sofifa.com/players/158/023/21_60.png
# 1      https://cdn.sofifa.com/players/020/801/21_60.png
# 2      https://cdn.sofifa.com/players/200/389/21_60.png
# 3      https://cdn.sofifa.com/players/192/985/21_60.png
# 4      https://cdn.sofifa.com/players/190/871/21_60.png
# ...                                                 ...
# 18974  https://cdn.sofifa.com/players/257/710/21_60.png
# 18975  https://cdn.sofifa.com/players/258/736/21_60.png
# 18976  https://cdn.sofifa.com/players/247/223/21_60.png
# 18977  https://cdn.sofifa.com/players/258/760/21_60.png
# 18978  https://cdn.sofifa.com/players/255/958/21_60.png
#
#                            LongName  \
# 0                      Lionel Messi
# 1      C. Ronaldo dos Santos Aveiro
# 2                         Jan Oblak
# 3                   Kevin De Bruyne
# 4        Neymar da Silva Santos Jr.
# ...                             ...
# ...

# %%
#Replacing \n\n with an empty space
fifa_data['Team & Contract'] = fifa_data['Team & Contract'].str. replace('\n\n', '')

# %%
fifa_data
# Out:
#                                                photoUrl  \
# 0      https://cdn.sofifa.com/players/158/023/21_60.png
# 1      https://cdn.sofifa.com/players/020/801/21_60.png
# 2      https://cdn.sofifa.com/players/200/389/21_60.png
# 3      https://cdn.sofifa.com/players/192/985/21_60.png
# 4      https://cdn.sofifa.com/players/190/871/21_60.png
# ...                                                 ...
# 18974  https://cdn.sofifa.com/players/257/710/21_60.png
# 18975  https://cdn.sofifa.com/players/258/736/21_60.png
# 18976  https://cdn.sofifa.com/players/247/223/21_60.png
# 18977  https://cdn.sofifa.com/players/258/760/21_60.png
# 18978  https://cdn.sofifa.com/players/255/958/21_60.png
#
#                            LongName  \
# 0                      Lionel Messi
# 1      C. Ronaldo dos Santos Aveiro
# 2                         Jan Oblak
# 3                   Kevin De Bruyne
# 4        Neymar da Silva Santos Jr.
# ...                             ...
# ...

# %%
#Replacing \n with an empty space
fifa_data['Team & Contract'] = fifa_data['Team & Contract'].str. replace('\n',   '  ,')

# %%
#Displaying the content
fifa_data
# Out:
#                                                photoUrl  \
# 0      https://cdn.sofifa.com/players/158/023/21_60.png
# 1      https://cdn.sofifa.com/players/020/801/21_60.png
# 2      https://cdn.sofifa.com/players/200/389/21_60.png
# 3      https://cdn.sofifa.com/players/192/985/21_60.png
# 4      https://cdn.sofifa.com/players/190/871/21_60.png
# ...                                                 ...
# 18974  https://cdn.sofifa.com/players/257/710/21_60.png
# 18975  https://cdn.sofifa.com/players/258/736/21_60.png
# 18976  https://cdn.sofifa.com/players/247/223/21_60.png
# 18977  https://cdn.sofifa.com/players/258/760/21_60.png
# 18978  https://cdn.sofifa.com/players/255/958/21_60.png
#
#                            LongName  \
# 0                      Lionel Messi
# 1      C. Ronaldo dos Santos Aveiro
# 2                         Jan Oblak
# 3                   Kevin De Bruyne
# 4        Neymar da Silva Santos Jr.
# ...                             ...
# ...

# %%
#Replacing '~' with  '-'
fifa_data['Team & Contract'] = fifa_data['Team & Contract'].str. replace(' ~', '-')

# %%
#Displaying the first five rows
fifa_data.head()
# Out:
#                                            photoUrl  \
# 0  https://cdn.sofifa.com/players/158/023/21_60.png
# 1  https://cdn.sofifa.com/players/020/801/21_60.png
# 2  https://cdn.sofifa.com/players/200/389/21_60.png
# 3  https://cdn.sofifa.com/players/192/985/21_60.png
# 4  https://cdn.sofifa.com/players/190/871/21_60.png
#
#                        LongName  \
# 0                  Lionel Messi
# 1  C. Ronaldo dos Santos Aveiro
# 2                     Jan Oblak
# 3               Kevin De Bruyne
# 4    Neymar da Silva Santos Jr.
#
#                                            playerUrl Nationality Positions  \
# 0  http://sofifa.com/player/158023/lionel-messi/2...   Argentina  RW ST CF
# 1  http://sofifa.com/player/20801/c-ronaldo-dos-s...    Portugal     ST LW
# 2  http://sofifa.com/player/200389/jan-oblak/210005/    Slovenia        GK
# 3  http://sofifa.com/player/192985/kevin-de-bruyn...     Belgium    CAM CM
# ...

# %%
#converting Hits column to a string
fifa_data['Hits'] = fifa_data['Hits'].astype(str)

# %%
#Replacing \n with an empty space
fifa_data['Hits'] = fifa_data['Hits'].str. replace('\n','')

# %%
#Displaying the first five row
fifa_data.head()
# Out:
#                                            photoUrl  \
# 0  https://cdn.sofifa.com/players/158/023/21_60.png
# 1  https://cdn.sofifa.com/players/020/801/21_60.png
# 2  https://cdn.sofifa.com/players/200/389/21_60.png
# 3  https://cdn.sofifa.com/players/192/985/21_60.png
# 4  https://cdn.sofifa.com/players/190/871/21_60.png
#
#                        LongName  \
# 0                  Lionel Messi
# 1  C. Ronaldo dos Santos Aveiro
# 2                     Jan Oblak
# 3               Kevin De Bruyne
# 4    Neymar da Silva Santos Jr.
#
#                                            playerUrl Nationality Positions  \
# 0  http://sofifa.com/player/158023/lionel-messi/2...   Argentina  RW ST CF
# 1  http://sofifa.com/player/20801/c-ronaldo-dos-s...    Portugal     ST LW
# 2  http://sofifa.com/player/200389/jan-oblak/210005/    Slovenia        GK
# 3  http://sofifa.com/player/192985/kevin-de-bruyn...     Belgium    CAM CM
# ...

# %%
#Displaying a subset of fifa_data and printing out the first five
fifa_data[['Joined', 'Value', 'Wage', 'Release Clause', 'W/F', 'SM', 'IR']].head()
# Out:
#          Joined   Value   Wage Release Clause  W/F  SM   IR
# 0   Jul 1, 2004  €67.5M  €560K        €138.4M  4 ★  4★  5 ★
# 1  Jul 10, 2018    €46M  €220K         €75.9M  4 ★  5★  5 ★
# 2  Jul 16, 2014    €75M  €125K        €159.4M  3 ★  1★  3 ★
# 3  Aug 30, 2015    €87M  €370K          €161M  5 ★  4★  4 ★
# 4   Aug 3, 2017    €90M  €270K        €166.5M  5 ★  5★  5 ★

# %%
#Replacing ★ with an empty space
fifa_data['W/F'] = fifa_data['W/F'].str. replace('★','')

fifa_data['SM'] = fifa_data['SM'].str. replace('★','')

fifa_data['IR'] = fifa_data['IR'].str. replace('★','')

# %%
#Displaying the first twenty of the subset

fifa_data[['Joined', 'Value', 'Wage', 'Release Clause', 'W/F', 'SM', 'IR']].head(20)
# Out:
#           Joined    Value   Wage Release Clause W/F SM  IR
# 0    Jul 1, 2004   €67.5M  €560K        €138.4M  4   4  5
# 1   Jul 10, 2018     €46M  €220K         €75.9M  4   5  5
# 2   Jul 16, 2014     €75M  €125K        €159.4M  3   1  3
# 3   Aug 30, 2015     €87M  €370K          €161M  5   4  4
# 4    Aug 3, 2017     €90M  €270K        €166.5M  5   5  5
# 5    Jul 1, 2014     €80M  €240K          €132M  4   4  4
# 6    Jul 1, 2018  €105.5M  €160K        €203.1M  4   5  3
# 7   Jul 19, 2018   €62.5M  €160K        €120.3M  3   1  3
# 8    Jul 1, 2017     €78M  €250K        €144.3M  3   4  3
# 9    Jul 1, 2016     €78M  €250K        €144.3M  4   4  3
# 10   Jan 1, 2018   €75.5M  €210K        €145.3M  3   2  3
# 11   Jul 1, 2014   €69.5M  €260K        €147.7M  4   1  3
# 12  Jul 11, 2013   €59.5M  €310K          €122M  3   2  3
# 13   Aug 9, 2018     €56M  €250K          €119M  3   1  4
# 14   Jul 1, 2011     €29M  €125K         €47.9M  4   1  5
# ...

# %%
#Displaying the last twenty rows of the fifa_data subset
fifa_data[['Joined', 'Value', 'Wage', 'Release Clause', 'W/F', 'SM', 'IR']].tail(20)
# Out:
#              Joined Value  Wage Release Clause W/F SM  IR
# 18959   Jan 1, 2020  €50K  €700          €101K  2   2  1
# 18960   Feb 1, 2019  €45K   €1K           €79K  2   2  1
# 18961  Aug 15, 2020  €60K  €600          €137K  3   2  1
# 18962  Aug 28, 2019  €60K  €550          €143K  3   2  1
# 18963  Feb 14, 2020  €30K  €500           €53K  1   1  1
# 18964   Aug 3, 2020  €35K   €2K           €57K  3   2  1
# 18965  Sep 22, 2020  €50K   €2K           €88K  3   2  1
# 18966   Mar 8, 2019  €60K  €500          €131K  2   2  1
# 18967  Jul 29, 2019  €45K   €2K           €79K  3   2  1
# 18968   Feb 1, 2019  €35K   €1K           €57K  2   2  1
# 18969   Feb 9, 2018  €45K   €1K           €79K  2   2  1
# 18970   Aug 1, 2020  €40K   €1K           €72K  2   2  1
# 18971   Aug 1, 2020  €30K   €2K           €47K  2   2  1
# 18972   Aug 1, 2020  €35K   €1K           €61K  2   2  1
# 18973   Aug 1, 2020  €40K   €1K           €65K  2   2  1
# ...

# %%
#printing fifa_data columns
fifa_data.columns
# Out:
# Index(['photoUrl', 'LongName', 'playerUrl', 'Nationality', 'Positions', 'Name',
#        'Age', '↓OVA', 'POT', 'Team & Contract', 'ID', 'Height', 'Weight',
#        'foot', 'BOV', 'BP', 'Growth', 'Joined', 'Loan Date End', 'Value',
#        'Wage', 'Release Clause', 'Attacking', 'Crossing', 'Finishing',
#        'Heading Accuracy', 'Short Passing', 'Volleys', 'Skill', 'Dribbling',
#        'Curve', 'FK Accuracy', 'Long Passing', 'Ball Control', 'Movement',
#        'Acceleration', 'Sprint Speed', 'Agility', 'Reactions', 'Balance',
#        'Power', 'Shot Power', 'Jumping', 'Stamina', 'Strength', 'Long Shots',
#        'Mentality', 'Aggression', 'Interceptions', 'Positioning', 'Vision',
#        'Penalties', 'Composure', 'Defending', 'Marking', 'Standing Tackle',
#        'Sliding Tackle', 'Goalkeeping', 'GK Diving', 'GK Handling',
#        'GK Kicking', 'GK Positioning', 'GK Reflexes', 'Total Stats',
#        'Base Stats', 'W/F', 'SM', 'A/W', 'D/W', 'IR', 'PAC', 'SHO', 'PAS',
# ...

# %%
#printing a subset of the fifa_data
fifa_data['foot', 'BOV', 'BP', 'Growth', 'Joined','Loan Date End', 'Value']].head(40)
# Out:
#      foot  BOV   BP  Growth        Joined Loan Date End    Value
# 0    Left   93   RW       0   Jul 1, 2004           NaN   €67.5M
# 1   Right   92   ST       0  Jul 10, 2018           NaN     €46M
# 2   Right   91   GK       2  Jul 16, 2014           NaN     €75M
# 3   Right   91  CAM       0  Aug 30, 2015           NaN     €87M
# 4   Right   91   LW       0   Aug 3, 2017           NaN     €90M
# 5   Right   91   ST       0   Jul 1, 2014           NaN     €80M
# 6   Right   91   ST       5   Jul 1, 2018           NaN  €105.5M
# 7   Right   90   GK       1  Jul 19, 2018           NaN   €62.5M
# 8    Left   90   RW       0   Jul 1, 2017           NaN     €78M
# 9   Right   90   LW       0   Jul 1, 2016           NaN     €78M
# 10  Right   90   CB       1   Jan 1, 2018           NaN   €75.5M
# 11  Right   90   GK       3   Jul 1, 2014           NaN   €69.5M
# 12  Right   89  CDM       0  Jul 11, 2013           NaN   €59.5M
# ...

# %%
# deleting the  Loan Date End from fifa_data  because it seems  to carry NAN value all through
fifa_data.drop(columns = 'Loan Date End', inplace = True)

# %%
#checking whether the specified column has been dropped
fifa_data.columns
# Out:
# Index(['photoUrl', 'LongName', 'playerUrl', 'Nationality', 'Positions', 'Name',
#        'Age', '↓OVA', 'POT', 'Team & Contract', 'ID', 'Height', 'Weight',
#        'foot', 'BOV', 'BP', 'Growth', 'Joined', 'Value', 'Wage',
#        'Release Clause', 'Attacking', 'Crossing', 'Finishing',
#        'Heading Accuracy', 'Short Passing', 'Volleys', 'Skill', 'Dribbling',
#        'Curve', 'FK Accuracy', 'Long Passing', 'Ball Control', 'Movement',
#        'Acceleration', 'Sprint Speed', 'Agility', 'Reactions', 'Balance',
#        'Power', 'Shot Power', 'Jumping', 'Stamina', 'Strength', 'Long Shots',
#        'Mentality', 'Aggression', 'Interceptions', 'Positioning', 'Vision',
#        'Penalties', 'Composure', 'Defending', 'Marking', 'Standing Tackle',
#        'Sliding Tackle', 'Goalkeeping', 'GK Diving', 'GK Handling',
#        'GK Kicking', 'GK Positioning', 'GK Reflexes', 'Total Stats',
#        'Base Stats', 'W/F', 'SM', 'A/W', 'D/W', 'IR', 'PAC', 'SHO', 'PAS',
# ...

# %%
#displaying a subset of fifa_data to make that the data is properly clean
fifa_data[['foot', 'BOV', 'BP', 'Growth', 'Joined', 'Value', 'Wage']].head(40)
# Out:
#      foot  BOV   BP  Growth        Joined    Value   Wage
# 0    Left   93   RW       0   Jul 1, 2004   €67.5M  €560K
# 1   Right   92   ST       0  Jul 10, 2018     €46M  €220K
# 2   Right   91   GK       2  Jul 16, 2014     €75M  €125K
# 3   Right   91  CAM       0  Aug 30, 2015     €87M  €370K
# 4   Right   91   LW       0   Aug 3, 2017     €90M  €270K
# 5   Right   91   ST       0   Jul 1, 2014     €80M  €240K
# 6   Right   91   ST       5   Jul 1, 2018  €105.5M  €160K
# 7   Right   90   GK       1  Jul 19, 2018   €62.5M  €160K
# 8    Left   90   RW       0   Jul 1, 2017     €78M  €250K
# 9   Right   90   LW       0   Jul 1, 2016     €78M  €250K
# 10  Right   90   CB       1   Jan 1, 2018   €75.5M  €210K
# 11  Right   90   GK       3   Jul 1, 2014   €69.5M  €260K
# 12  Right   89  CDM       0  Jul 11, 2013   €59.5M  €310K
# 13   Left   89   GK       1   Aug 9, 2018     €56M  €250K
# 14  Right   89   GK       0   Jul 1, 2011     €29M  €125K
# ...

# %%
#displaying a subset of fifa_data to make that the data is properly clean
fifa_data[['DRI', 'DEF', 'PHY', 'Hits']].tail(40)
# Out:
#        DRI  DEF  PHY Hits
# 18939   50   41   56    1
# 18940   30   48   56    1
# 18941   51   43   48    1
# 18942   52   38   40    5
# 18943   50   26   46    2
# 18944   47   17   53    4
# 18945   50   39   49    5
# 18946   48   47   44    2
# 18947   46   38   58    3
# 18948   51   30   44    1
# 18949   30   50   51    3
# 18950   55   44   56    2
# 18951   30   49   58    2
# 18952   50   28   47    3
# 18953   33   49   53    2
# 18954   48   34   46    4
# 18955   44   15   44    2
# 18956   51   24   37    5
# 18957   44   39   51    9
# 18958   39   49   49    1
# 18959   46   44   58    2
# 18960   48   46   53    1
# 18961   45   48   51    1
# 18962   49   44   67    1
# 18963   50   20   45    6
# 18964   49   48   41    1
# 18965   49   30   44   12
# 18966   46   40   53    5
# 18967   42   45   55    3
# 18968   36   45   55   15
# 18969   44   39   46    4
# 18970   47   43   48    2
# 18971   46   40   59    8
# 18972   30   47   55    2
# ...

# %%
#Exporting my clean data to an excel sheet called FootBall
fifa_data.to_csv('FootBall.csv', index=False, header=False)
